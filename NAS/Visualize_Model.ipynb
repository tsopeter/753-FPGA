# %%
from visualize_model import *
from read_model_stats import *

file = './4-bit-4-mse-fixed/2025-04-27-22-37-46-229384'
text = open(f'{file}-history.txt').read()
history = read_history(text)
df = get_loss_dataframe(history, mode='min')
plot_loss_heatmaps(df)
read_stats(file)
# Out:
# Model [5.  3.  0.5] has
# 	Validation Loss: 0.04572054681210808
# 	Validation Accuracy: 0.5544
# (array(0.04572055), array([5. , 3. , 0.5]), array(0.5544))
