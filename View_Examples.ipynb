# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./spi-controller-cmod-a7/spi-controller-cmod-a7.runs/impl_1/iladata_4900_4.csv')
X = df['design_1/design_1_i/probe1_0_1[7:0]'][1:].to_numpy().astype(np.uint8)[1:4901].reshape(70,70)
plt.imshow(X,cmap='grey')
plt.axis('off')
plt.show()
len(X)
# Out:
# 70

# %%
X
# Out:
# array([[149, 147, 145, ..., 148, 148, 147],
#        [146, 147, 145, ..., 148, 148, 147],
#        [146, 147, 144, ..., 147, 147, 146],
#        ...,
#        [104, 107, 108, ...,  81,  79,  76],
#        [106, 107, 109, ...,  81,  78,  77],
#        [107, 108, 110, ...,  84,  81,  78]], dtype=uint8)
