# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./spi-controller-cmod-a7/spi-controller-cmod-a7.runs/impl_1/iladata_4096_0.csv')
X = df['design_1/design_1_i/probe1_0_1[7:0]'][1:].to_numpy().astype(np.uint8)[1:4097].reshape(64,64)
plt.imshow(X,cmap='grey')
plt.axis('off')
plt.show()
len(X)
# Out:
# 64
